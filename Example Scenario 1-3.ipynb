# %%
from SPARQLWrapper import SPARQLWrapper, JSON, POST
import json, os
from query_util import *

queryString = open('query1_3.sparql').read()
print(queryString)

result = process_query(queryString)
# Out:
# #Query 1000 images, each image has atleast a label car
#
# prefix cv: <http://vision.semkg.org/onto/v0.1/>
#
# SELECT DISTINCT ?image
# {
#     ?image a cv:Image.
#     ?image cv:hasAnnotation ?annotation.
#     ?annotation cv:hasAnnotatedObject ?cat.
#     ?cat cv:hasLabel ?label.
#     FILTER (?label = "car")
# }
# LIMIT 2
# {'annotations': [{'area': 95.202,
#    'bbox': [173.64, 143.96, 17.63, 5.4],
#    'category_id': 0,
#    'id': 0,
#    'image_id': 199951,
#    'iscrowd': 0},
#   {'area': 117.8777,
#    'bbox': [53.04, 151.53, 25.57, 4.61],
#    'category_id': 0,
#    'id': 1,
#    'image_id': 199951,
#    'iscrowd': 0},
#   {'area': 4382.0322,
#    'bbox': [311.48, 239.06, 92.82, 47.21],
#    'category_id': 1,
#    'id': 2,
#    'image_id': 199951,
#    'iscrowd': 0},
#   {'area': 1268.3568,
#    'bbox': [336.96, 231.65, 42.72, 29.69],
#    'category_id': 2,
#    'id': 3,
#    'image_id': 199951,
#    'iscrowd': 0},
#   {'area': 87.67110000000001,
# ...
